# %% [markdown]
# # 1 . Sentiment Analysis

# %%
# !pip install openai

# %%
import openai
import pandas as pd

# %%
# Authenticate with OpenAI API
openai.api_key = "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"

# %%
# Fine-tune GPT-3 on financial data
data = pd.read_csv("/content/drive/MyDrive/AI_Research/financial_data.csv",encoding="ISO-8859-1",names=['Sentiment','text'])

model_engine = "text-davinci-002"
prompt = "Sentiment analysis of financial data: "
fin_data = data["text"].tolist()
results = []
for data in fin_data[100]:
    prompt = prompt + data + " "
response = openai.Completion.create(engine=model_engine, prompt=prompt, max_tokens=50)
results.append(response.choices[0].text)

# Print the results
for result in results:
    print(result)
# Out:
# Positive
